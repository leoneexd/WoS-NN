# %%
import numpy as np
from numpy.linalg import norm
import math, random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#spatial funcs for WoS

def closestPoint(v, s):
    u = s[1] - s[0]
    rate = max(0, min(u.dot(v - s[0])/u.dot(u), 1))
    return (s[0] + rate*(s[1] - s[0]))

def shortestDistance(v, segments):
    r = float("inf")
    for s in segments:
        u = closestPoint(v, s)
        if norm(v - u) < r:
            r = norm(v - u)
    return r

# %%
#WoS solver
'''record info for all the valid paths
    a list of list having path-steps (start -> boundary end) (dynamic length), 
    a list of list having radius 
    a list of boundary results, 
    a final local estimation
'''
def solver(v, segments, g, eps = 0.01, nWalks = 10000, maxSteps = 16, maxR = 0.2):
    vWalks = 0   
    sumEst = 0
    paths = []
    boundary = []
    for i in range(0, nWalks):
        x0 = v
        path = []
        for step in range(0, maxSteps): 
            path.append(x0)
            r = min([shortestDistance(x0, segments), maxR])
            if r < eps: 
                sumEst += g(x0)
                boundary.append(g(x0))
                vWalks += 1
                paths.append(path)
                #print("walk: " + str(vWalks) + " hit " + str(x0) + " boundary " + str(g(x0)))
                break
            theta = random.uniform(0, 2*math.pi)
            x0 = x0 + np.array([r * math.cos(theta), r * math.sin(theta)])
        
    if vWalks == 0:
        return 0
    return paths, boundary, sumEst/vWalks

# %%
# set up the problem
segments = [np.array([[-1, -1], [-1, 1]]), np.array([[-1, -1], [1, -1]]), np.array([[1, -1], [1, 1]]), np.array([[-1, 1], [1, 1]])]
v = np.array([0.5, 0.5])
def boundary(v):
    return 2*v[0] + 3*v[1]

# %%
paths, boundary, result = solver(v, segments, boundary)
#print(paths[1])

# %%
class ZNN(keras.Model):
    def __init__(self, units):
        super(ZNN, self).__init__()
        self.layer1 = keras.layers.Dense(units[0], activation='relu')
        self.layer2 = keras.layers.Dense(units[1], activation='relu')
        self.layer3 = keras.layers.Dense(units[2], activation='relu')
        self.bn = keras.layers.BatchNormalization()
        self.outputs = layers.Dense(2)

    def call(self, input_tensor, training):
        x = self.layer1(input_tensor)
        x = self.layer2(x)
        x = self.layer3(x)
        x = self.bn(x, training)
        x = self.outputs(x)
        #print(x.shape)
        return x

# %%
class NNsolver(keras.Model):
    def __init__(self, est, paths, boundary):
        super(NNsolver, self).__init__()
        #self.paths, self.radius, self.boundary, self.est = data
        self.est = est
        self.paths = paths
        self.boundary = boundary
        self.model = ZNN([32, 64, 128])
        self.optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=1e-2 , epsilon=1e-8)

    def loss_fn(self, y_pred, y):
        delta = y_pred - y
        loss = tf.square(delta)
        return loss

    def train_step(self, x, training):
        y_pred = self.est
        for i in range(len(x) - 1):
            z = self.model(x[i].reshape(1,2).astype("float32"), training) #obtain gradients for steps
            y_pred += tf.reduce_sum(z * np.array(x[i + 1] - x[i]), 1, keepdims=True) #accumulating
        return y_pred

    def train(self): 
        training_history = []
        for i in range(len(self.paths)):
            with tf.GradientTape() as tape:
                y_pred = self.train_step(np.array(self.paths[i]), training = True)
                loss = self.loss_fn(y_pred,self.boundary[i])

            training_vars = self.model.trainable_variables
            print(loss)
            grad = tape.gradient(loss, training_vars)
            self.optimizer.apply_gradients(zip(grad, training_vars))
            
            training_history.append([i, loss])

        return training_history

    def test1(self, v):
        return self.model(v.reshape(1,2).astype("float32"), training = True)

    def test2(self, path):
        return self.train_step(path, training = True)

# %%
training = NNsolver(result, paths, boundary)

training_history = training.train() #no epoch
# Out:
# tf.Tensor([[0.07070465]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.25054747]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.5729287]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.29645804]], shape=(1, 1), dtype=float32)
# tf.Tensor([[47.115036]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5585862]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1054739]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11679756]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.90071887]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1486036]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00853491]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2376386]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8803436]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12694876]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05670004]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03455623]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11322354]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.73561347]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.576367]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02448624]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09689762]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11273406]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.102853]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.79136574]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.52314633]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03999363]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11489739]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0100047]], shape=(1, 1), dtype=float32)
# tf.Tensor([[4.025406]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8651409]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.37382352]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.6044662]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.28180444]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1283787]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21936953]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11724368]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00939136]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15690525]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17670882]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.26497126]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04304328]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2562745]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03434232]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.29171583]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07705981]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2680821]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00973643]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04379573]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11599034]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00609972]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12151292]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.31791195]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00034161]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.29891375]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00093156]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04197435]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.505934]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1230222]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.30027276]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05642333]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02698445]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04887503]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.70648694]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01011245]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.6796498]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01016344]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0226917]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00685697]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00926183]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04114874]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03173341]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.47623137]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.0757732]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3028785]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01455943]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03137833]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09734209]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21683267]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3680102]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.42952484]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01062948]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01741166]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3774105]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09865508]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00010426]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15976213]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01495733]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00494807]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00054815]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0143648]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.36769292]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.5584519]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00534495]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01580013]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01401593]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.39455503]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3894328]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01431986]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.761604]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17985913]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.9492325]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00217542]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14073507]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4055638]], shape=(1, 1), dtype=float32)
# tf.Tensor([[4.2292056]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.33938318]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9401768]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.2380602]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04432621]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06944832]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.7057596]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.5458212]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16483921]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0112795]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00496889]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.26837823]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16781963]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15446484]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.1301246]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0389301]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09877374]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08794913]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08814425]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05475676]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19062287]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1387681]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00567493]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2921436]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.271587]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.6261207e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07813945]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04388059]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.4667588]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10499817]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2952286e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5113023]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.31971127]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.060293]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11697477]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09891001]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.81493175]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10677993]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14473206]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08118822]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3163553]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22904886]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00572988]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23694843]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18309827]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00523115]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0168947]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08179505]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6730765]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03453921]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10498859]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5155431]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05582991]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02077737]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00258169]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5290866]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07355406]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.33013254]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1084185]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08279828]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.79509]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.6606847]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02950423]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0184753]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0009664]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22255392]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03165998]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00023169]], shape=(1, 1), dtype=float32)
# tf.Tensor([[7.3374376]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04554053]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.712819]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05203464]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.916326]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03199728]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9504742]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00275512]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00266642]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5635018]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.8914584]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01178426]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01615332]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01336305]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.3829033]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.2132568]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00323365]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.189487]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02045231]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2476776]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00046633]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2833438]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06916399]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10503618]], shape=(1, 1), dtype=float32)
# tf.Tensor([[4.4975095e-06]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.8984184]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0852277]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05838083]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18512526]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00574776]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23997526]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06437713]], shape=(1, 1), dtype=float32)
# tf.Tensor([[13.087174]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0047089]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.65222394]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00443211]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02152576]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19044074]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4683728]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.1254268]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04598619]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19246581]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.561998]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06917904]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11188535]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.899068]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.37183347]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19500832]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.54962945]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18271448]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6866442]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14610182]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13230053]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14135103]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.148386]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.36666515]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20561838]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.48257962]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20744127]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3522294]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01790577]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.39560404]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03867086]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.34343144]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00972937]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5631085]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1672791]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20674406]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.68099725]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19952905]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27639517]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.26763594]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.50022125]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13445398]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.46926445]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07241555]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05346479]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0091183]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00366327]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00200004]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9801935]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00678954]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03894694]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.31283456]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00809544]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27158502]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00650125]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4500068]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1161918]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17388606]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0034098]], shape=(1, 1), dtype=float32)
# tf.Tensor([[7.636986e-06]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00015231]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.682669]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04051253]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10365715]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7302661]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5183513]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08862355]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00612298]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.43647105]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08873118]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24062671]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.55775076]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00110471]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01128456]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22823305]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00480694]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00027137]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13535279]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2869107]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.80691534]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5945567]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8656191]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03266604]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00440567]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04814752]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.3257018]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.48174158]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00995036]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15077166]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14259109]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09107073]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.7282274]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01564414]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.088305]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00559661]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01085563]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9009384]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00790356]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15159225]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8101422]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14978494]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4491819]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00042817]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01290085]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.96767986]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.80925536]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00065726]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17081377]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04788902]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04729587]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04024683]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20073687]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1669745]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00908995]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9278605]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.7758071]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1284701]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04621379]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0206923]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23844606]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.57048535]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00921759]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.46639794]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04401894]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4322621]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05083137]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08194596]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.31550807]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23282841]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00238456]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.55825835]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00014356]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07671893]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06095376]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.66220504]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01570868]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07332172]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08032424]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01388206]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02429225]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04350145]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13460404]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03054651]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00086884]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11323525]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6454585]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5921886]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15673342]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7762636]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07679661]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3377617]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22149456]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23034418]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3290091]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05325033]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02856194]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.6874518]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.544469]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02219338]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06460115]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02405479]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00527161]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05357488]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03949418]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.201066]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.845703]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11619831]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04734815]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10825983]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00550209]], shape=(1, 1), dtype=float32)
# tf.Tensor([[10.61147]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.8212655]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.46897247]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.27312]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24415587]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01184376]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01034499]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09405056]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00010681]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7913874]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3137025]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.69586563]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1859092]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03608417]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03362014]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16786125]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00118947]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.7925377e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.7702351]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00281158]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02227728]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18150333]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00159002]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02224477]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7255203]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21669458]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.32332352]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0024605]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09008024]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0255372]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01688621]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.3539202]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04579916]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.55060345]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03144644]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5204971]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01726643]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0215045]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.279174]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.9892652]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.3317568]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14459114]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.5716938]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4364619]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6888963]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06325735]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01287481]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7921278]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06157197]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21405743]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1095723]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6352887]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2700024]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00138519]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05329468]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2610602]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01018922]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09411915]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09410598]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15038957]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00173995]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01785641]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00234666]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0859872]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02437102]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00846804]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00029666]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01996096]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.28019658]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.919524]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24902487]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04855666]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05147976]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0375819]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8079218]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.64142513]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.73382]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.46716547]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01215128]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18817395]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4725684]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00428879]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5982801]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01133482]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00036668]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06694242]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.8102827]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07651066]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3789914]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00631081]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.44115728]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.031887]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01240266]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00046564]], shape=(1, 1), dtype=float32)
# tf.Tensor([[4.4815946]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02163475]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01416831]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21040389]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.5213394]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05997542]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01261106]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.150693]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.8972102]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9389478]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14874312]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.7980881]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0433514]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07384014]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.48686117]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10763457]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.39582527]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13171062]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08463404]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09141901]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08951055]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19421212]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.70977044]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15742946]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09373043]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11865861]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08710876]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.29255965]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08037209]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4222268]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.37905774]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00026199]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05281976]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.7769823e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03452256]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20584093]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.747052]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00475544]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.585455]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05564518]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.65459794]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11338998]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21959202]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.380496]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08341894]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04165063]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3078036]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8710638]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00134913]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0715205]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02478569]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24093932]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.114132]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0328516]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10315529]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00278544]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02122716]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5952845]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1042412]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05560244]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.8095636]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13632394]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1729901]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07282714]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05044648]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02515066]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.53955424]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02002954]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1011437]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01123255]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17076983]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10580115]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7558477]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03094449]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.40374443]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02624583]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12994605]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8469381]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0440844]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5103242]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19640563]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00116031]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08580848]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.41201976]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07164616]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11139034]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3575898]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04076197]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00900269]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06414794]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27421924]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.36307457]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00468351]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.45315668]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1917786]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18783446]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01101209]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7700666]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2556754]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02623417]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7250048]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00119102]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.36091083]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.90818506]], shape=(1, 1), dtype=float32)
# tf.Tensor([[16.27853]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01451579]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02400053]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24681942]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02510856]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.28261632]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19983865]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9871422]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17104797]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.8216]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7946634]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13544017]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.1997955]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1856227]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.55000174]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1242363]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.773234]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.48797774]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07894152]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27267975]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01190871]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00478488]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.32620612]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13470097]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.0475118]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.53644985]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00148874]], shape=(1, 1), dtype=float32)
# tf.Tensor([[8.961272]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2162907]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03552054]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02884768]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5393165]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4049591]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7403845]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14547168]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9317481]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0149707]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11952005]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00454732]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17958805]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.38859752]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00769253]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.6550994e-06]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.39091623]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.35023963]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1095456]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.83819294]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.49640787]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5051837]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00874896]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9351038]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0386432]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02273222]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1033747]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16731818]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2477131]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01806948]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09197029]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2607069]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0166341]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0074436]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05431936]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03447048]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0420533]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07888392]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03303369]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3274713]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.612022]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.371077]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04817442]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.40027425]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06697202]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.42126992]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15675664]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6215275]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22509024]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20544264]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00249575]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4753466]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1436921]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02695955]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03427563]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.34239942]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00503357]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22494367]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13330525]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24732712]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3379427]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.9245821]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.2340639]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04741613]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3138828]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03218786]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0664029]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00480681]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21445848]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.69077873]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00952362]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08422489]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.883437]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9117348]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18445212]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03685847]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10062458]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08419694]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.25301263]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00226624]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7149351]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10812023]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04590259]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03115556]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07550223]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00328628]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13861042]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.43757686]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.35130715]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15625392]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.5130092]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08178578]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3434197]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12089886]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7632932]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00851545]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27626485]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.28883797]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00157549]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16333087]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.65992844]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.93264264]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.39038095]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.48906824]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.032809]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23711535]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00371886]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04376001]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.83183783]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00575706]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17256333]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.28660992]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.56890035]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1529047]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0091182]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00459753]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.014092]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21587186]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15000573]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00319203]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03396779]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4814239]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0255145]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.25311455]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11014772]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13480741]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20630373]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24828634]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.70105505]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.36473346]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05424225]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9859847]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20496354]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.4955301]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01626308]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7994531]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3204016]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12982781]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00276417]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6001411]], shape=(1, 1), dtype=float32)
# tf.Tensor([[8.828625e-07]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02362277]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0063018]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.53062385]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07367206]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00010371]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09594836]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07284129]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03544159]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.44671783]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0018648]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01059293]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.46017098]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.30699593]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03470771]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20110449]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03946803]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00724001]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01787808]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01430936]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09123701]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03513265]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02524391]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.30957943]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13467437]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23398049]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1694282]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12155498]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2733258]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01414698]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09375203]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.41462797]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01821174]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0833284]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09390336]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00856432]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.951911]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00047764]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17661923]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02166436]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18756878]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00283742]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15433311]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12987988]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11206087]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01439208]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00572393]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3991299]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16894336]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03526291]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0092654]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.30342144]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.836617]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18557094]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.64653546]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.70317465]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00241666]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0940738]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00206481]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00160838]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.25190428]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3412366]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14771892]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8534866]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02590159]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15809235]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.69685644]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00406483]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00258741]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.41526073]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05292853]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06490073]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08818106]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04754539]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.41586107]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00018113]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0164322]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.34320766]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.35449532]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04003675]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.31603488]], shape=(1, 1), dtype=float32)
# tf.Tensor([[19.785772]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00305675]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9294137]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.53504294]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01443169]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20074177]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9399544]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5357819]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19562113]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.68523437]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.47728792]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.56630296]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2905045]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7936427]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.71028876]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8526529]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6491653]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.33777586]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.44954312]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.368776]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23084518]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6194575]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.71397305]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.93001455]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.25116006]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10202692]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21362944]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27329686]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5412129]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23984703]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6015194]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05089117]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08281928]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.86328447]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09889097]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09556486]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15377203]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23630452]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04829035]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27962112]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09116688]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21313076]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.2765348]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14733101]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3428496]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00699686]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17861718]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17277019]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6354168]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13626198]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2603644]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12374678]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01491129]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01383839]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03906965]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6558709]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13300632]], shape=(1, 1), dtype=float32)
# ...
# tf.Tensor([[0.00050456]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.146102]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00624149]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.242915]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6279134]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00222759]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00477068]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07446262]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2925924]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.40323317]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02864936]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02371792]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02303417]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.36576974]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00137341]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03981094]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.33314905]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.31490627]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.25871566]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2740257]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03876844]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12063041]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00168226]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.241047]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12772875]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13560095]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04168772]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09700333]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.37874544]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0768389]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5534512]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10628267]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00016964]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06703819]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03357181]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03637788]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05691939]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7188752]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13201588]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.30692673]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2814246]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02271066]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.346045]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0312386]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00608892]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04102648]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.9843034]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03993015]], shape=(1, 1), dtype=float32)
# tf.Tensor([[5.3704753e-08]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.113574]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00743805]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.660905]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.74532366]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1567706]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.23896232]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.64869434]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19582386]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1259206]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27032757]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00065593]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09958886]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00986431]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05716173]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.15102339]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14257056]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7733712]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6891833]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5360675]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.76428753]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.59131414]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00141513]], shape=(1, 1), dtype=float32)
# tf.Tensor([[7.930634e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4294414]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02061206]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11117242]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17387055]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05387772]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0693943]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2700024]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.63270766]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08659597]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00519335]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.45348832]], shape=(1, 1), dtype=float32)
# tf.Tensor([[5.400508]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1355697]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00335097]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.202655]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4225491]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02050663]], shape=(1, 1), dtype=float32)
# tf.Tensor([[4.8238187e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5279946]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.820313]], shape=(1, 1), dtype=float32)
# tf.Tensor([[16.757532]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5161852]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.33034572]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06627025]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2561456]], shape=(1, 1), dtype=float32)
# tf.Tensor([[6.471085]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.38347712]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10059161]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.75523263]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24450706]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.87887007]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9569829]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.52208495]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.1919663]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4169919]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4965305]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4234767]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.50859755]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.79693365]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3214378]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3655065]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2205539]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9272552]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4069269]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.5132213]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13040867]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.93832874]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03229548]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00999874]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04359598]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18575586]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00808227]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0733509]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.28159463]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00235837]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3211786]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.4489937]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04647165]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.70794]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.506204]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03233989]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06866566]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04558348]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0038967]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0301551]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13379335]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27915636]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.36647403]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00356324]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14576428]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.8644553]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12121341]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.94088805]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01133771]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.41699466]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10027593]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.40849614]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09807408]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.0868665]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.36240143]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.608511]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07592341]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.39633858]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11605515]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27566943]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00163193]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.900308]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00120929]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00528231]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19397873]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00413015]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.98099434]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17332618]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.47853923]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0842851]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21969102]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.32554603]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16899373]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.60793066]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24705377]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2539835]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.37610775]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.21873571]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7635711]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0251704]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3220691]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.93285495]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05064727]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07292742]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.27831903]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02236655]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.26865596]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11372807]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01174226]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18307379]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02646941]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.452336]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.97666967]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.30520517]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11643851]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16657276]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.26269615]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.60802585]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02123682]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.08455263]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00633462]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.49417424]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.81648517]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07575125]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02310384]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03303698]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.16502976]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5863339]], shape=(1, 1), dtype=float32)
# tf.Tensor([[16.91802]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04722455]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.3986357e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01858811]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02273323]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1463]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.7931374]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22357863]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02077091]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.28871036]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01107212]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00181059]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.3399371]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.224676]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05210003]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0786084]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13442495]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.25176287]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04707886]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1261537]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24842083]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.19100612]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.2499721]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.49529043]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0193548]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.6682053]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5318876]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00161663]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00147545]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1727129]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07059832]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02445729]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00722144]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00897159]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.5551069]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.29632747]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00723636]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.12471653]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00292052]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00561532]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4782942]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.383932e-06]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.41813937]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01206339]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00104018]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.26589915]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22170533]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00795873]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.5961465e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.07713262]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02202683]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.31448123]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.09565952]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.6126281]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04904996]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.1044154]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06200828]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.06342585]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.25365463]], shape=(1, 1), dtype=float32)
# tf.Tensor([[3.4795573]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02064931]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14324346]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2675057]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04237113]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.57924354]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.24236214]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0192766]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05306014]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.4192429]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03312753]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.13220271]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02500409]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05913456]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00192407]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6621899]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00712154]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.55121183]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00580717]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05020836]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.11801413]], shape=(1, 1), dtype=float32)
# tf.Tensor([[1.6843944e-05]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1386429]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01544658]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.7246125]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.00735795]], shape=(1, 1), dtype=float32)
# tf.Tensor([[2.0134952]], shape=(1, 1), dtype=float32)
# tf.Tensor([[7.9292693]], shape=(1, 1), dtype=float32)

# %%
print(training.test1(np.array([1, 2])))
# Out:
# tf.Tensor([[0.6173847 2.0436563]], shape=(1, 2), dtype=float32)

# %%
print(training.test2(paths[3]))
print(paths[3])
print(boundary[3])
# Out:
# tf.Tensor([[0.40614]], shape=(1, 1), dtype=float32)
# [array([0.5, 0.5]), array([0.45937594, 0.69583076]), array([0.2742628 , 0.77154817]), array([0.47325056, 0.75145168]), array([0.38894846, 0.93281639]), array([0.39585153, 0.86598836]), array([0.32760815, 0.98132249]), array([0.3109782 , 0.97281988]), array([0.29425908, 0.95139023]), array([0.32961211, 0.91802749]), array([0.2771199 , 0.98098828]), array([0.25882348, 0.98615417]), array([0.24900062, 0.99591216])]
# 0.2479827459787678
